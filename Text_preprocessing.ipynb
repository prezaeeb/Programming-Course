# %% [markdown]
# # Toekization

# %%
text = "Tokenization is the process of splitting text into words or phrases."
tokens = text.split()
print(tokens)
# Out:
# ['Tokenization', 'is', 'the', 'process', 'of', 'splitting', 'text', 'into', 'words', 'or', 'phrases.']

# %%
text = "Parisa is not teaching well."
tokens2 = text.split()
tokens2
# Out:
# ['Parisa', 'is', 'not', 'teaching', 'well.']

# %%
text3 = "Tokenization is important! It helps in NLP."
tokens3 = text3.split()
tokens3
# Out:
# ['Tokenization', 'is', 'important!', 'It', 'helps', 'in', 'NLP.']

# %%
import nltk
from nltk.tokenize import word_tokenize

nltk.download('punkt')  # Required once
text = "Tokenization is important! It helps in NLP."
tokens = word_tokenize(text)
print(tokens)
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/parisarezaeeborj/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# ['Tokenization', 'is', 'important', '!', 'It', 'helps', 'in', 'NLP', '.']

# %%
from nltk.tokenize import sent_tokenize

text = "Hello world! Tokenization is important. It helps process text."
sentences = sent_tokenize(text)
print(sentences)
# Out:
# ['Hello world!', 'Tokenization is important.', 'It helps process text.']

# %%
import nltk
import string
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer

# %%
# Download required NLTK data
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')

# Sample text
text = """
    Natural Language Processing (NLP) is a field of artificial intelligence that focuses on the interaction
    between computers and human (natural) languages. It enables machines to understand, interpret, and generate
    human language, allowing for effective communication between humans and machines.
"""

# Step 1: Convert text to lowercase
text = text.lower()

# Step 2: Tokenization (split the text into words)
tokens = word_tokenize(text)

# Step 3: Remove punctuation
tokens = [word for word in tokens if word not in string.punctuation]

# Step 4: Remove stopwords (commonly used words like 'the', 'and', 'a', etc.)
stop_words = set(stopwords.words("english"))
tokens = [word for word in tokens if word not in stop_words]

# Step 5: Lemmatization (converting words to their base form)
lemmatizer = WordNetLemmatizer()
tokens = [lemmatizer.lemmatize(word) for word in tokens]

# Print the preprocessed tokens
print("Preprocessed Text:")
print(tokens)

# Count the frequency of each word
word_freq = Counter(tokens)

# Step 6: Get the top 3 most frequent words
top_3_words = word_freq.most_common(3)

# Print the top 3 words and their frequency
print("Top 3 Most Frequent Words:", top_3_words)

# Step 7: Plot the frequency of the top 3 words
words, frequencies = zip(*top_3_words)

plt.bar(words, frequencies)
plt.xlabel('Words')
plt.ylabel('Frequency')
plt.title('Top 3 Most Frequent Words')
plt.show()
# Out:
# Preprocessed Text:
# ['natural', 'language', 'processing', 'nlp', 'field', 'artificial', 'intelligence', 'focus', 'interaction', 'computer', 'human', 'natural', 'language', 'enables', 'machine', 'understand', 'interpret', 'generate', 'human', 'language', 'allowing', 'effective', 'communication', 'human', 'machine']
# Top 3 Most Frequent Words: [('language', 3), ('human', 3), ('natural', 2)]
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/parisarezaeeborj/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/parisarezaeeborj/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/parisarezaeeborj/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')

# Sample text
text2 = """
    These are short, famous texts in English from classic sources like the Bible or Shakespeare. Some texts have word definitions and explanations to help you. Some of these texts are written in an old style of English. Try to understand them, because the English that we speak today is based on what our great, great, great, great grandparents spoke before! Of course, not all these texts were originally written in English. The Bible, for example, is a translation. But they are all well known in English today, and many of them express beautiful thoughts.
"""

# Step 1: Convert text to lowercase
tex2t = text2.lower()

# Step 2: Tokenization (split the text into words)
tokens = word_tokenize(text2)

# Step 3: Remove punctuation
tokens = [word for word in tokens if word not in string.punctuation]

# Step 4: Remove stopwords (commonly used words like 'the', 'and', 'a', etc.)
stop_words = set(stopwords.words("english"))
tokens = [word for word in tokens if word not in stop_words]

# Step 5: Lemmatization (converting words to their base form)
lemmatizer = WordNetLemmatizer()
tokens = [lemmatizer.lemmatize(word) for word in tokens]

# Print the preprocessed tokens
print("Preprocessed Text:")
print(tokens)

# Count the frequency of each word
word_freq = Counter(tokens)

# Step 6: Get the top 3 most frequent words
top_3_words = word_freq.most_common(3)

# Print the top 3 words and their frequency
print("Top 3 Most Frequent Words:", top_3_words)

# Step 7: Plot the frequency of the top 3 words
words, frequencies = zip(*top_3_words)

plt.bar(words, frequencies)
plt.xlabel('Words')
plt.ylabel('Frequency')
plt.title('Top 3 Most Frequent Words')
plt.show()
# Out:
# Preprocessed Text:
# ['These', 'short', 'famous', 'text', 'English', 'classic', 'source', 'like', 'Bible', 'Shakespeare', 'Some', 'text', 'word', 'definition', 'explanation', 'help', 'Some', 'text', 'written', 'old', 'style', 'English', 'Try', 'understand', 'English', 'speak', 'today', 'based', 'great', 'great', 'great', 'great', 'grandparent', 'spoke', 'Of', 'course', 'text', 'originally', 'written', 'English', 'The', 'Bible', 'example', 'translation', 'But', 'well', 'known', 'English', 'today', 'many', 'express', 'beautiful', 'thought']
# Top 3 Most Frequent Words: [('English', 5), ('text', 4), ('great', 4)]
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/parisarezaeeborj/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/parisarezaeeborj/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# ...
