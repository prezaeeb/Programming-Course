# %% [markdown]
# import the breast cancer dataset from sklearn

# %% [markdown]
# import it to the pandas dataframe

# %% [markdown]
# get an idea of the data by looking at some rows and the columns

# %% [markdown]
# compute the mean, std, min, and other type of statistics of the data

# %% [markdown]
# plot the histogram for each feature

# %% [markdown]
# use scatter plot to show how the features relate to each other with some Scatter plots.
